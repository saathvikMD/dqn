# %% [markdown]
# <a href="https://colab.research.google.com/github/saathvikMD/dqn/blob/main/cnn_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import torch
import random
import matplotlib.pyplot as plt
import numpy as np
import os
os.environ.setdefault('PATH', '')
from collections import deque
import gym
from gym import spaces
import cv2
cv2.ocl.setUseOpenCL(False)
from gym.wrappers import TimeLimit


class NoopResetEnv(gym.Wrapper):
    def __init__(self, env, noop_max=30):

        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def reset(self, **kwargs):
       
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = self.unwrapped.np_random.randint(1, self.noop_max + 1) 
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, done, _ = self.env.step(self.noop_action)
            if done:
                obs = self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)

class FireResetEnv(gym.Wrapper):
    def __init__(self, env):
     
        gym.Wrapper.__init__(self, env)
        assert env.unwrapped.get_action_meanings()[1] == 'FIRE'
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def reset(self, **kwargs):
        self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(1)
        if done:
            self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(2)
        if done:
            self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)

class EpisodicLifeEnv(gym.Wrapper):
    def __init__(self, env):

        gym.Wrapper.__init__(self, env)
        self.lives = 0
        self.was_real_done  = True

    def step(self, action):
        obs, reward, done, info = self.env.step(action)
        self.was_real_done = done

        lives = self.env.unwrapped.ale.lives()
        if lives < self.lives and lives > 0:

            done = True
        self.lives = lives
        return obs, reward, done, info

    def reset(self, **kwargs):
        """Reset only when lives are exhausted.
        This way all states are still reachable even though lives are episodic,
        and the learner need not know about any of this behind-the-scenes.
        """
        if self.was_real_done:
            obs = self.env.reset(**kwargs)
        else:

            obs, _, _, _ = self.env.step(0)
        self.lives = self.env.unwrapped.ale.lives()
        return obs

class MaxAndSkipEnv(gym.Wrapper):
    def __init__(self, env, skip=4):
        """Return only every `skip`-th frame"""
        gym.Wrapper.__init__(self, env)

        self._obs_buffer = np.zeros((2,)+env.observation_space.shape, dtype=np.uint8)
        self._skip       = skip

    def step(self, action):
        """Repeat action, sum reward, and max over last observations."""
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            if i == self._skip - 2: self._obs_buffer[0] = obs
            if i == self._skip - 1: self._obs_buffer[1] = obs
            total_reward += reward
            if done:
                break

        max_frame = self._obs_buffer.max(axis=0)

        return max_frame, total_reward, done, info

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)

class ClipRewardEnv(gym.RewardWrapper):
    def __init__(self, env):
        gym.RewardWrapper.__init__(self, env)

    def reward(self, reward):
        """Bin reward to {+1, 0, -1} by its sign."""
        return np.sign(reward)


class WarpFrame(gym.ObservationWrapper):
    def __init__(self, env, width=84, height=84, grayscale=True, dict_space_key=None):
        """
        Warp frames to 84x84 as done in the Nature paper and later work.

        If the environment uses dictionary observations, `dict_space_key` can be specified which indicates which
        observation should be warped.
        """
        super().__init__(env)
        self._width = width
        self._height = height
        self._grayscale = grayscale
        self._key = dict_space_key
        if self._grayscale:
            num_colors = 1
        else:
            num_colors = 3

        new_space = gym.spaces.Box(
            low=0,
            high=255,
            shape=(self._height, self._width, num_colors),
            dtype=np.uint8,
        )
        if self._key is None:
            original_space = self.observation_space
            self.observation_space = new_space
        else:
            original_space = self.observation_space.spaces[self._key]
            self.observation_space.spaces[self._key] = new_space
        assert original_space.dtype == np.uint8 and len(original_space.shape) == 3

    def observation(self, obs):
        if self._key is None:
            frame = obs
        else:
            frame = obs[self._key]

        if self._grayscale:
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(
            frame, (self._width, self._height), interpolation=cv2.INTER_AREA
        )
        if self._grayscale:
            frame = np.expand_dims(frame, -1)

        if self._key is None:
            obs = frame
        else:
            obs = obs.copy()
            obs[self._key] = frame
        return obs


class FrameStack(gym.Wrapper):
    def __init__(self, env, k):
        """Stack k last frames.

        Returns lazy array, which is much more memory efficient.

        See Also
        --------
        baselines.common.atari_wrappers.LazyFrames
        """
        gym.Wrapper.__init__(self, env)
        self.k = k
        self.frames = deque([], maxlen=k)
        shp = env.observation_space.shape
        self.observation_space = spaces.Box(low=0, high=255, shape=(shp[:-1] + (shp[-1] * k,)), dtype=env.observation_space.dtype)

    def reset(self):
        ob = self.env.reset()
        for _ in range(self.k):
            self.frames.append(ob)
        return self._get_ob()

    def step(self, action):
        ob, reward, done, info = self.env.step(action)
        self.frames.append(ob)
        return self._get_ob(), reward, done, info

    def _get_ob(self):
        assert len(self.frames) == self.k
        return LazyFrames(list(self.frames))

class ScaledFloatFrame(gym.ObservationWrapper):
    def __init__(self, env):
        gym.ObservationWrapper.__init__(self, env)
        self.observation_space = gym.spaces.Box(low=0, high=1, shape=env.observation_space.shape, dtype=np.float32)

    def observation(self, observation):
        return np.array(observation).astype(np.float32) / 255.0

class LazyFrames(object):
    def __init__(self, frames):

        self._frames = frames
        self._out = None

    def _force(self):
        if self._out is None:
            self._out = np.concatenate(self._frames, axis=-1)
            self._frames = None
        return self._out

    def __array__(self, dtype=None):
        out = self._force()
        if dtype is not None:
            out = out.astype(dtype)
        return out

    def __len__(self):
        return len(self._force())

    def __getitem__(self, i):
        return self._force()[i]

    def count(self):
        frames = self._force()
        return frames.shape[frames.ndim - 1]

    def frame(self, i):
        return self._force()[..., i]

def make_atari(env_id, max_episode_steps=None):
    env = gym.make(env_id)
    assert 'NoFrameskip' in env.spec.id
    env = NoopResetEnv(env, noop_max=30)
    env = MaxAndSkipEnv(env, skip=4)
    if max_episode_steps is not None:
        env = TimeLimit(env, max_episode_steps=max_episode_steps)
    return env

def wrap_deepmind(env, episode_life=True, clip_rewards=True, frame_stack=False, scale=False):
    """Configure environment for DeepMind-style Atari.
    """
    if episode_life:
        env = EpisodicLifeEnv(env)
    if 'FIRE' in env.unwrapped.get_action_meanings():
        env = FireResetEnv(env)
    env = WarpFrame(env)
    if scale:
        env = ScaledFloatFrame(env)
    if clip_rewards:
        env = ClipRewardEnv(env)
    if frame_stack:
        env = FrameStack(env, 4)
    return env

# %%
env = make_atari('BreakoutNoFrameskip-v4')
env = wrap_deepmind(env)

# %%
seed_value = 23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)

num_episodes = 5
rewards_total = []

for i in range(num_episodes):
  state = env.reset()
  score = 0
  while True:
    action = env.action_space.sample()

    new_state, reward, done, info = env.step(action)

    score += reward


    if done:
      rewards_total.append(score)
      print('Episode finished. Reward: %i step' % score)    
      break

print('Average rerward %.2f' %(sum(rewards_total)/num_episodes))
print('Average rerward last hunred %.2f' %(sum(rewards_total[-100:])/100))

plt.figure(figsize = (12,5))
plt.title('Rewards')
plt.plot(rewards_total, alpha = 0.6, color = 'green')
plt.show()

env.close()
env.env.close()
# Out:
# Episode finished. Reward: 1 step
# Episode finished. Reward: 2 step
# Episode finished. Reward: 0 step
# Episode finished. Reward: 1 step
# Episode finished. Reward: 0 step
# Average rerward 0.80
# Average rerward last hunred 0.04

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import gym
import random
import math
import time
import os.path

import matplotlib.pyplot as plt

plt.style.use('ggplot')

use_cuda = torch.cuda.is_available()

device = torch.device("cuda:0" if use_cuda else "cpu")
Tensor = torch.Tensor
LongTensor = torch.LongTensor

env_id = "BreakoutNoFrameskip-v4"
env = make_atari(env_id)
env = wrap_deepmind(env)

directory = './BreakoutVideos/'
env = gym.wrappers.Monitor(env, directory, video_callable=lambda episode_id: episode_id%100==0, force = True)


seed_value = 23
env.seed(seed_value)
torch.manual_seed(seed_value)
random.seed(seed_value)


learning_rate = 0.0001
num_episodes = 1000000
gamma = 0.99

hidden_layer = 512

replay_mem_size = 100000
batch_size = 32

update_target_frequency = 5000

double_dqn = True

egreedy = 0.9
egreedy_final = 0.01
egreedy_decay = 10000

report_interval = 10
score_to_solve = 600

clip_error = True
normalize_image = True

file2save = 'breakout_save.pth'
save_model_frequency = 10
resume_previous_training = False



number_of_inputs = env.observation_space.shape[0]
number_of_outputs = env.action_space.n

def calculate_epsilon(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
              math.exp(-1. * steps_done / egreedy_decay )
    return epsilon

def load_model():
    return torch.load(file2save)

def save_model(model):
    torch.save(model.state_dict(), file2save)
    
def preprocess_frame(frame):
    frame = frame.transpose((2,0,1))
    frame = torch.from_numpy(frame)
    frame = frame.to(device, dtype=torch.float32)
    frame = frame.unsqueeze(1)
    
    return frame

def plot_results():
    plt.figure(figsize=(12,5))
    plt.title("Rewards")
    plt.plot(rewards_total, alpha=0.6, color='red')
    plt.savefig("Breakout-results.png")
    plt.close()

class ExperienceReplay(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0
 
    def push(self, state, action, new_state, reward, done):
        transition = (state, action, new_state, reward, done)
        
        if self.position >= len(self.memory):
            self.memory.append(transition)
        else:
            self.memory[self.position] = transition
        
        self.position = ( self.position + 1 ) % self.capacity
        
        
    def sample(self, batch_size):
        return zip(*random.sample(self.memory, batch_size))
        
        
    def __len__(self):
        return len(self.memory)
        
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1)
        
        self.advantage1 = nn.Linear(7*7*64,hidden_layer)
        self.advantage2 = nn.Linear(hidden_layer, number_of_outputs)
        
        self.value1 = nn.Linear(7*7*64,hidden_layer)
        self.value2 = nn.Linear(hidden_layer,1)

        self.activation = nn.ReLU()
        
        
    def forward(self, x):
        
        if normalize_image:
            x = x / 255
        
        output_conv = self.conv1(x)
        output_conv = self.activation(output_conv)
        output_conv = self.conv2(output_conv)
        output_conv = self.activation(output_conv)
        output_conv = self.conv3(output_conv)
        output_conv = self.activation(output_conv)
        
        output_conv = output_conv.view(output_conv.size(0), -1) 
        
        output_advantage = self.advantage1(output_conv)
        output_advantage = self.activation(output_advantage)
        output_advantage = self.advantage2(output_advantage)
        
        output_value = self.value1(output_conv)
        output_value = self.activation(output_value)
        output_value = self.value2(output_value)
        
        output_final = output_value + output_advantage - output_advantage.mean()

        return output_final
    
class QNet_Agent(object):
    def __init__(self):
        self.nn = NeuralNetwork().to(device)
        self.target_nn = NeuralNetwork().to(device)

        self.loss_func = nn.MSELoss()
        
        
        self.optimizer = optim.Adam(params=self.nn.parameters(), lr=learning_rate)
      
        
        self.number_of_frames = 0
        
        if resume_previous_training and os.path.exists(file2save):
            print("Loading previously saved model ... ")
            self.nn.load_state_dict(load_model())
        
    def select_action(self,state,epsilon):
        
        random_for_egreedy = torch.rand(1)[0]
        
        if random_for_egreedy > epsilon:      
            
            with torch.no_grad():
                
                state = preprocess_frame(state)
                action_from_nn = self.nn(state)
                
                action = torch.max(action_from_nn,1)[1]
                action = action.item()        
        else:
            action = env.action_space.sample()
        
        return action
    
    def optimize(self):
        
        if (len(memory) < batch_size):
            return
        
        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state = [ preprocess_frame(frame) for frame in state ] 
        state = torch.cat(state)
        
        new_state = [ preprocess_frame(frame) for frame in new_state ] 
        new_state = torch.cat(new_state)

        reward = Tensor(reward).to(device)
        action = LongTensor(action).to(device)
        done = Tensor(done).to(device)


        if double_dqn:
            new_state_indexes = self.nn(new_state).detach()
            max_new_state_indexes = torch.max(new_state_indexes, 1)[1]  
            
            new_state_values = self.target_nn(new_state).detach()
            max_new_state_values = new_state_values.gather(1, max_new_state_indexes.unsqueeze(1)).squeeze(1)
        else:
            new_state_values = self.target_nn(new_state).detach()
            max_new_state_values = torch.max(new_state_values, 1)[0]
        
        
        target_value = reward + ( 1 - done ) * gamma * max_new_state_values
  
        predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)
        
        loss = self.loss_func(predicted_value, target_value)
    
        self.optimizer.zero_grad()
        loss.backward()
        
        if clip_error:
            for param in self.nn.parameters():
                param.grad.data.clamp_(-1,1)
        
        self.optimizer.step()
        
        if self.number_of_frames % update_target_frequency == 0:
            self.target_nn.load_state_dict(self.nn.state_dict())
        
        if self.number_of_frames % save_model_frequency == 0:
            save_model(self.nn)
        
        self.number_of_frames += 1
        
        
        

memory = ExperienceReplay(replay_mem_size)
qnet_agent = QNet_Agent()

rewards_total = []

frames_total = 0 
solved_after = 0
solved = False

start_time = time.time()

for i_episode in range(num_episodes):
    
    state = env.reset()
    
    score = 0
    j = 0
    while True:
        
        frames_total += 1
        
        epsilon = calculate_epsilon(frames_total)
        
     
        action = qnet_agent.select_action(state, epsilon)
        
        new_state, reward, done, info = env.step(action)
        
        score += reward

        memory.push(state, action, new_state, reward, done)
        qnet_agent.optimize()
        
        state = new_state
        
        if done:
          j +=1

        if done and j == 1:
            rewards_total.append(score)
            print('episoede :' + str(i_episode + 1), ' score :' + str(score))
            
            mean_reward_100 = sum(rewards_total[-100:])/100
            
            if (mean_reward_100 > score_to_solve and solved == False):
                print("SOLVED! After %i episodes " % i_episode)
                solved_after = i_episode
                solved = True
            
            if (i_episode % report_interval == 0 and i_episode > 0):
                
                plot_results()
                
                print("\n*** Episode %i *** \
                      \nAv.reward: [last %i]: %.2f, [last 100]: %.2f, [all]: %.2f \
                      \nepsilon: %.2f, frames_total: %i" 
                  % 
                  ( i_episode,
                    report_interval,
                    sum(rewards_total[-report_interval:])/report_interval,
                    mean_reward_100,
                    sum(rewards_total)/len(rewards_total),
                    epsilon,
                    frames_total
                          ) 
                  )
                  
                elapsed_time = time.time() - start_time
                print("Elapsed time: ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))



            break
        

print("\n\n\n\nAverage reward: %.2f" % (sum(rewards_total)/num_episodes))
print("Average reward (last 100 episodes): %.2f" % (sum(rewards_total[-100:])/100))
if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# Streaming output truncated to the last 5000 lines.
# episoede :16415  score :1.0
# episoede :16416  score :4.0
# episoede :16417  score :4.0
# episoede :16418  score :2.0
# episoede :16419  score :1.0
# episoede :16420  score :2.0
# episoede :16421  score :12.0
#
# *** Episode 16420 ***
# Av.reward: [last 10]: 2.90, [last 100]: 3.56, [all]: 2.27
# epsilon: 0.01, frames_total: 1630880
# Elapsed time:  08:50:03
# episoede :16422  score :4.0
# episoede :16423  score :3.0
# episoede :16424  score :4.0
# episoede :16425  score :0.0
# episoede :16426  score :10.0
# episoede :16427  score :1.0
# episoede :16428  score :9.0
# episoede :16429  score :3.0
# episoede :16430  score :3.0
# episoede :16431  score :8.0
#
# *** Episode 16430 ***
# Av.reward: [last 10]: 4.50, [last 100]: 3.63, [all]: 2.27
# epsilon: 0.01, frames_total: 1632623
# Elapsed time:  08:50:36
# episoede :16432  score :1.0
# episoede :16433  score :1.0
# episoede :16434  score :1.0
# episoede :16435  score :1.0
# episoede :16436  score :4.0
# episoede :16437  score :3.0
# episoede :16438  score :3.0
# episoede :16439  score :1.0
# episoede :16440  score :3.0
# episoede :16441  score :8.0
#
# *** Episode 16440 ***
# Av.reward: [last 10]: 2.60, [last 100]: 3.61, [all]: 2.27
# epsilon: 0.01, frames_total: 1633792
# Elapsed time:  08:50:58
# episoede :16442  score :5.0
# episoede :16443  score :0.0
# episoede :16444  score :2.0
# episoede :16445  score :0.0
# episoede :16446  score :8.0
# episoede :16447  score :1.0
# episoede :16448  score :1.0
# episoede :16449  score :1.0
# episoede :16450  score :1.0
# episoede :16451  score :6.0
#
# *** Episode 16450 ***
# Av.reward: [last 10]: 2.50, [last 100]: 3.42, [all]: 2.27
# epsilon: 0.01, frames_total: 1634855
# Elapsed time:  08:51:19
# episoede :16452  score :4.0
# episoede :16453  score :1.0
# episoede :16454  score :2.0
# episoede :16455  score :0.0
# episoede :16456  score :13.0
# episoede :16457  score :1.0
# episoede :16458  score :5.0
# episoede :16459  score :2.0
# episoede :16460  score :0.0
# episoede :16461  score :7.0
#
# *** Episode 16460 ***
# Av.reward: [last 10]: 3.50, [last 100]: 3.38, [all]: 2.27
# epsilon: 0.01, frames_total: 1636314
# Elapsed time:  08:51:46
# episoede :16462  score :3.0
# episoede :16463  score :5.0
# episoede :16464  score :1.0
# episoede :16465  score :2.0
# episoede :16466  score :4.0
# episoede :16467  score :1.0
# episoede :16468  score :5.0
# episoede :16469  score :4.0
# episoede :16470  score :1.0
# episoede :16471  score :8.0
#
# *** Episode 16470 ***
# Av.reward: [last 10]: 3.40, [last 100]: 3.36, [all]: 2.27
# epsilon: 0.01, frames_total: 1637674
# Elapsed time:  08:52:12
# episoede :16472  score :1.0
# episoede :16473  score :1.0
# episoede :16474  score :1.0
# episoede :16475  score :1.0
# episoede :16476  score :9.0
# episoede :16477  score :4.0
# episoede :16478  score :2.0
# episoede :16479  score :2.0
# episoede :16480  score :2.0
# episoede :16481  score :11.0
#
# *** Episode 16480 ***
# Av.reward: [last 10]: 3.40, [last 100]: 3.44, [all]: 2.27
# epsilon: 0.01, frames_total: 1639213
# Elapsed time:  08:52:41
# episoede :16482  score :1.0
# episoede :16483  score :1.0
# episoede :16484  score :1.0
# episoede :16485  score :2.0
# episoede :16486  score :2.0
# episoede :16487  score :3.0
# episoede :16488  score :3.0
# episoede :16489  score :6.0
# episoede :16490  score :1.0
# episoede :16491  score :17.0
#
# *** Episode 16490 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.50, [all]: 2.27
# epsilon: 0.01, frames_total: 1640650
# Elapsed time:  08:53:08
# episoede :16492  score :3.0
# episoede :16493  score :1.0
# episoede :16494  score :2.0
# episoede :16495  score :1.0
# episoede :16496  score :17.0
# episoede :16497  score :3.0
# episoede :16498  score :1.0
# episoede :16499  score :2.0
# episoede :16500  score :1.0
# episoede :16501  score :4.0
#
# *** Episode 16500 ***
# Av.reward: [last 10]: 3.50, [last 100]: 3.42, [all]: 2.27
# epsilon: 0.01, frames_total: 1642046
# Elapsed time:  08:53:35
# episoede :16502  score :4.0
# episoede :16503  score :2.0
# episoede :16504  score :1.0
# episoede :16505  score :0.0
# episoede :16506  score :10.0
# episoede :16507  score :2.0
# episoede :16508  score :1.0
# episoede :16509  score :1.0
# episoede :16510  score :1.0
# episoede :16511  score :8.0
#
# *** Episode 16510 ***
# Av.reward: [last 10]: 3.00, [last 100]: 3.30, [all]: 2.27
# epsilon: 0.01, frames_total: 1643331
# Elapsed time:  08:54:00
# episoede :16512  score :6.0
# episoede :16513  score :9.0
# episoede :16514  score :3.0
# episoede :16515  score :2.0
# episoede :16516  score :17.0
# episoede :16517  score :0.0
# episoede :16518  score :2.0
# episoede :16519  score :1.0
# episoede :16520  score :1.0
# episoede :16521  score :6.0
#
# *** Episode 16520 ***
# Av.reward: [last 10]: 4.70, [last 100]: 3.48, [all]: 2.27
# epsilon: 0.01, frames_total: 1645135
# Elapsed time:  08:54:34
# episoede :16522  score :1.0
# episoede :16523  score :2.0
# episoede :16524  score :2.0
# episoede :16525  score :1.0
# episoede :16526  score :9.0
# episoede :16527  score :4.0
# episoede :16528  score :5.0
# episoede :16529  score :2.0
# episoede :16530  score :0.0
# episoede :16531  score :9.0
#
# *** Episode 16530 ***
# Av.reward: [last 10]: 3.50, [last 100]: 3.38, [all]: 2.27
# epsilon: 0.01, frames_total: 1646523
# Elapsed time:  08:55:00
# episoede :16532  score :4.0
# episoede :16533  score :4.0
# episoede :16534  score :2.0
# episoede :16535  score :0.0
# episoede :16536  score :9.0
# episoede :16537  score :3.0
# episoede :16538  score :1.0
# episoede :16539  score :1.0
# episoede :16540  score :1.0
# episoede :16541  score :12.0
#
# *** Episode 16540 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.49, [all]: 2.27
# epsilon: 0.01, frames_total: 1648058
# Elapsed time:  08:55:29
# episoede :16542  score :5.0
# episoede :16543  score :3.0
# episoede :16544  score :1.0
# episoede :16545  score :3.0
# episoede :16546  score :11.0
# episoede :16547  score :0.0
# episoede :16548  score :1.0
# episoede :16549  score :2.0
# episoede :16550  score :1.0
# episoede :16551  score :12.0
#
# *** Episode 16550 ***
# Av.reward: [last 10]: 3.90, [last 100]: 3.63, [all]: 2.28
# epsilon: 0.01, frames_total: 1649702
# Elapsed time:  08:56:00
# episoede :16552  score :2.0
# episoede :16553  score :4.0
# episoede :16554  score :1.0
# episoede :16555  score :1.0
# episoede :16556  score :9.0
# episoede :16557  score :2.0
# episoede :16558  score :2.0
# episoede :16559  score :3.0
# episoede :16560  score :1.0
# episoede :16561  score :1.0
#
# *** Episode 16560 ***
# Av.reward: [last 10]: 2.60, [last 100]: 3.54, [all]: 2.28
# epsilon: 0.01, frames_total: 1650891
# Elapsed time:  08:56:23
# episoede :16562  score :3.0
# episoede :16563  score :5.0
# episoede :16564  score :4.0
# episoede :16565  score :3.0
# episoede :16566  score :0.0
# episoede :16567  score :1.0
# episoede :16568  score :0.0
# episoede :16569  score :3.0
# episoede :16570  score :2.0
# episoede :16571  score :9.0
#
# *** Episode 16570 ***
# Av.reward: [last 10]: 3.00, [last 100]: 3.50, [all]: 2.28
# epsilon: 0.01, frames_total: 1652189
# Elapsed time:  08:56:47
# episoede :16572  score :4.0
# episoede :16573  score :7.0
# episoede :16574  score :0.0
# episoede :16575  score :0.0
# episoede :16576  score :9.0
# episoede :16577  score :4.0
# episoede :16578  score :2.0
# episoede :16579  score :4.0
# episoede :16580  score :0.0
# episoede :16581  score :13.0
#
# *** Episode 16580 ***
# Av.reward: [last 10]: 4.30, [last 100]: 3.59, [all]: 2.28
# epsilon: 0.01, frames_total: 1653838
# Elapsed time:  08:57:19
# episoede :16582  score :3.0
# episoede :16583  score :2.0
# episoede :16584  score :0.0
# episoede :16585  score :5.0
# episoede :16586  score :9.0
# episoede :16587  score :4.0
# episoede :16588  score :2.0
# episoede :16589  score :2.0
# episoede :16590  score :0.0
# episoede :16591  score :11.0
#
# *** Episode 16590 ***
# Av.reward: [last 10]: 3.80, [last 100]: 3.60, [all]: 2.28
# epsilon: 0.01, frames_total: 1655385
# Elapsed time:  08:57:48
# episoede :16592  score :3.0
# episoede :16593  score :3.0
# episoede :16594  score :1.0
# episoede :16595  score :1.0
# episoede :16596  score :2.0
# episoede :16597  score :3.0
# episoede :16598  score :2.0
# episoede :16599  score :1.0
# episoede :16600  score :1.0
# episoede :16601  score :1.0
#
# *** Episode 16600 ***
# Av.reward: [last 10]: 1.80, [last 100]: 3.43, [all]: 2.28
# epsilon: 0.01, frames_total: 1656288
# Elapsed time:  08:58:06
# episoede :16602  score :3.0
# episoede :16603  score :2.0
# episoede :16604  score :3.0
# episoede :16605  score :3.0
# episoede :16606  score :4.0
# episoede :16607  score :5.0
# episoede :16608  score :2.0
# episoede :16609  score :0.0
# episoede :16610  score :2.0
# episoede :16611  score :6.0
#
# *** Episode 16610 ***
# Av.reward: [last 10]: 3.00, [last 100]: 3.43, [all]: 2.28
# epsilon: 0.01, frames_total: 1657578
# Elapsed time:  08:58:31
# episoede :16612  score :1.0
# episoede :16613  score :2.0
# episoede :16614  score :4.0
# episoede :16615  score :3.0
# episoede :16616  score :9.0
# episoede :16617  score :7.0
# episoede :16618  score :4.0
# episoede :16619  score :1.0
# episoede :16620  score :1.0
# episoede :16621  score :2.0
#
# *** Episode 16620 ***
# Av.reward: [last 10]: 3.40, [last 100]: 3.30, [all]: 2.28
# epsilon: 0.01, frames_total: 1658874
# Elapsed time:  08:58:56
# episoede :16622  score :2.0
# episoede :16623  score :4.0
# episoede :16624  score :1.0
# episoede :16625  score :1.0
# episoede :16626  score :4.0
# episoede :16627  score :3.0
# episoede :16628  score :2.0
# episoede :16629  score :3.0
# episoede :16630  score :2.0
# episoede :16631  score :4.0
#
# *** Episode 16630 ***
# Av.reward: [last 10]: 2.60, [last 100]: 3.21, [all]: 2.28
# epsilon: 0.01, frames_total: 1659975
# Elapsed time:  08:59:17
# episoede :16632  score :4.0
# episoede :16633  score :5.0
# episoede :16634  score :1.0
# episoede :16635  score :0.0
# episoede :16636  score :14.0
# episoede :16637  score :4.0
# episoede :16638  score :4.0
# episoede :16639  score :0.0
# episoede :16640  score :5.0
# episoede :16641  score :10.0
#
# *** Episode 16640 ***
# Av.reward: [last 10]: 4.70, [last 100]: 3.31, [all]: 2.28
# epsilon: 0.01, frames_total: 1661832
# Elapsed time:  08:59:52
# episoede :16642  score :1.0
# episoede :16643  score :3.0
# episoede :16644  score :1.0
# episoede :16645  score :1.0
# episoede :16646  score :1.0
# episoede :16647  score :4.0
# episoede :16648  score :2.0
# episoede :16649  score :6.0
# episoede :16650  score :2.0
# episoede :16651  score :9.0
#
# *** Episode 16650 ***
# Av.reward: [last 10]: 3.00, [last 100]: 3.22, [all]: 2.28
# epsilon: 0.01, frames_total: 1663056
# Elapsed time:  09:00:15
# episoede :16652  score :4.0
# episoede :16653  score :4.0
# episoede :16654  score :3.0
# episoede :16655  score :3.0
# episoede :16656  score :12.0
# episoede :16657  score :2.0
# episoede :16658  score :5.0
# episoede :16659  score :0.0
# episoede :16660  score :1.0
# episoede :16661  score :13.0
#
# *** Episode 16660 ***
# Av.reward: [last 10]: 4.70, [last 100]: 3.43, [all]: 2.28
# epsilon: 0.01, frames_total: 1664853
# Elapsed time:  09:00:49
# episoede :16662  score :0.0
# episoede :16663  score :1.0
# episoede :16664  score :1.0
# episoede :16665  score :3.0
# episoede :16666  score :12.0
# episoede :16667  score :2.0
# episoede :16668  score :4.0
# episoede :16669  score :3.0
# episoede :16670  score :2.0
# episoede :16671  score :4.0
#
# *** Episode 16670 ***
# Av.reward: [last 10]: 3.20, [last 100]: 3.45, [all]: 2.28
# epsilon: 0.01, frames_total: 1666237
# Elapsed time:  09:01:15
# episoede :16672  score :2.0
# episoede :16673  score :0.0
# episoede :16674  score :4.0
# episoede :16675  score :0.0
# episoede :16676  score :12.0
# episoede :16677  score :3.0
# episoede :16678  score :2.0
# episoede :16679  score :4.0
# episoede :16680  score :2.0
# episoede :16681  score :9.0
#
# *** Episode 16680 ***
# Av.reward: [last 10]: 3.80, [last 100]: 3.40, [all]: 2.28
# epsilon: 0.01, frames_total: 1667838
# Elapsed time:  09:01:45
# episoede :16682  score :4.0
# episoede :16683  score :4.0
# episoede :16684  score :6.0
# episoede :16685  score :2.0
# episoede :16686  score :12.0
# episoede :16687  score :6.0
# episoede :16688  score :2.0
# episoede :16689  score :6.0
# episoede :16690  score :3.0
# episoede :16691  score :4.0
#
# *** Episode 16690 ***
# Av.reward: [last 10]: 4.90, [last 100]: 3.51, [all]: 2.29
# epsilon: 0.01, frames_total: 1669632
# Elapsed time:  09:02:19
# episoede :16692  score :4.0
# episoede :16693  score :1.0
# episoede :16694  score :2.0
# episoede :16695  score :2.0
# episoede :16696  score :6.0
# episoede :16697  score :3.0
# episoede :16698  score :4.0
# episoede :16699  score :3.0
# episoede :16700  score :0.0
# episoede :16701  score :12.0
#
# *** Episode 16700 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.70, [all]: 2.29
# epsilon: 0.01, frames_total: 1671113
# Elapsed time:  09:02:48
# episoede :16702  score :4.0
# episoede :16703  score :5.0
# episoede :16704  score :9.0
# episoede :16705  score :0.0
# episoede :16706  score :10.0
# episoede :16707  score :3.0
# episoede :16708  score :5.0
# episoede :16709  score :4.0
# episoede :16710  score :1.0
# episoede :16711  score :14.0
#
# *** Episode 16710 ***
# Av.reward: [last 10]: 5.50, [last 100]: 3.95, [all]: 2.29
# epsilon: 0.01, frames_total: 1673086
# Elapsed time:  09:03:26
# episoede :16712  score :0.0
# episoede :16713  score :2.0
# episoede :16714  score :1.0
# episoede :16715  score :2.0
# episoede :16716  score :13.0
# episoede :16717  score :1.0
# episoede :16718  score :2.0
# episoede :16719  score :1.0
# episoede :16720  score :3.0
# episoede :16721  score :12.0
#
# *** Episode 16720 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.98, [all]: 2.29
# epsilon: 0.01, frames_total: 1674665
# Elapsed time:  09:03:56
# episoede :16722  score :1.0
# episoede :16723  score :2.0
# episoede :16724  score :1.0
# episoede :16725  score :1.0
# episoede :16726  score :12.0
# episoede :16727  score :4.0
# episoede :16728  score :1.0
# episoede :16729  score :1.0
# episoede :16730  score :5.0
# episoede :16731  score :13.0
#
# *** Episode 16730 ***
# Av.reward: [last 10]: 4.10, [last 100]: 4.13, [all]: 2.29
# epsilon: 0.01, frames_total: 1676326
# Elapsed time:  09:04:27
# episoede :16732  score :3.0
# episoede :16733  score :0.0
# episoede :16734  score :2.0
# episoede :16735  score :3.0
# episoede :16736  score :6.0
# episoede :16737  score :6.0
# episoede :16738  score :5.0
# episoede :16739  score :3.0
# episoede :16740  score :0.0
# episoede :16741  score :13.0
#
# *** Episode 16740 ***
# Av.reward: [last 10]: 4.10, [last 100]: 4.07, [all]: 2.29
# epsilon: 0.01, frames_total: 1677975
# Elapsed time:  09:04:58
# episoede :16742  score :2.0
# episoede :16743  score :5.0
# episoede :16744  score :0.0
# episoede :16745  score :2.0
# episoede :16746  score :13.0
# episoede :16747  score :1.0
# episoede :16748  score :3.0
# episoede :16749  score :2.0
# episoede :16750  score :1.0
# episoede :16751  score :2.0
#
# *** Episode 16750 ***
# Av.reward: [last 10]: 3.10, [last 100]: 4.08, [all]: 2.29
# epsilon: 0.01, frames_total: 1679224
# Elapsed time:  09:05:22
# episoede :16752  score :1.0
# episoede :16753  score :0.0
# episoede :16754  score :1.0
# episoede :16755  score :6.0
# episoede :16756  score :10.0
# episoede :16757  score :2.0
# episoede :16758  score :2.0
# episoede :16759  score :5.0
# episoede :16760  score :2.0
# episoede :16761  score :11.0
#
# *** Episode 16760 ***
# Av.reward: [last 10]: 4.00, [last 100]: 4.01, [all]: 2.29
# epsilon: 0.01, frames_total: 1680887
# Elapsed time:  09:05:53
# episoede :16762  score :3.0
# episoede :16763  score :3.0
# episoede :16764  score :2.0
# episoede :16765  score :2.0
# episoede :16766  score :11.0
# episoede :16767  score :2.0
# episoede :16768  score :0.0
# episoede :16769  score :3.0
# episoede :16770  score :3.0
# episoede :16771  score :15.0
#
# *** Episode 16770 ***
# Av.reward: [last 10]: 4.40, [last 100]: 4.13, [all]: 2.29
# epsilon: 0.01, frames_total: 1682674
# Elapsed time:  09:06:28
# episoede :16772  score :3.0
# episoede :16773  score :0.0
# episoede :16774  score :3.0
# episoede :16775  score :1.0
# episoede :16776  score :2.0
# episoede :16777  score :10.0
# episoede :16778  score :0.0
# episoede :16779  score :4.0
# episoede :16780  score :2.0
# episoede :16781  score :14.0
#
# *** Episode 16780 ***
# Av.reward: [last 10]: 3.90, [last 100]: 4.14, [all]: 2.30
# epsilon: 0.01, frames_total: 1684315
# Elapsed time:  09:06:59
# episoede :16782  score :3.0
# episoede :16783  score :1.0
# episoede :16784  score :1.0
# episoede :16785  score :1.0
# episoede :16786  score :10.0
# episoede :16787  score :4.0
# episoede :16788  score :2.0
# episoede :16789  score :3.0
# episoede :16790  score :0.0
# episoede :16791  score :13.0
#
# *** Episode 16790 ***
# Av.reward: [last 10]: 3.80, [last 100]: 4.03, [all]: 2.30
# epsilon: 0.01, frames_total: 1685907
# Elapsed time:  09:07:29
# episoede :16792  score :2.0
# episoede :16793  score :2.0
# episoede :16794  score :2.0
# episoede :16795  score :4.0
# episoede :16796  score :12.0
# episoede :16797  score :5.0
# episoede :16798  score :1.0
# episoede :16799  score :0.0
# episoede :16800  score :0.0
# episoede :16801  score :12.0
#
# *** Episode 16800 ***
# Av.reward: [last 10]: 4.00, [last 100]: 4.06, [all]: 2.30
# epsilon: 0.01, frames_total: 1687581
# Elapsed time:  09:08:02
# episoede :16802  score :4.0
# episoede :16803  score :5.0
# episoede :16804  score :2.0
# episoede :16805  score :1.0
# episoede :16806  score :3.0
# episoede :16807  score :1.0
# episoede :16808  score :5.0
# episoede :16809  score :2.0
# episoede :16810  score :1.0
# episoede :16811  score :8.0
#
# *** Episode 16810 ***
# Av.reward: [last 10]: 3.20, [last 100]: 3.83, [all]: 2.30
# epsilon: 0.01, frames_total: 1688854
# Elapsed time:  09:08:27
# episoede :16812  score :3.0
# episoede :16813  score :7.0
# episoede :16814  score :2.0
# episoede :16815  score :2.0
# episoede :16816  score :2.0
# episoede :16817  score :2.0
# episoede :16818  score :1.0
# episoede :16819  score :4.0
# episoede :16820  score :1.0
# episoede :16821  score :1.0
#
# *** Episode 16820 ***
# Av.reward: [last 10]: 2.50, [last 100]: 3.71, [all]: 2.30
# epsilon: 0.01, frames_total: 1689828
# Elapsed time:  09:08:45
# episoede :16822  score :2.0
# episoede :16823  score :9.0
# episoede :16824  score :5.0
# episoede :16825  score :2.0
# episoede :16826  score :4.0
# episoede :16827  score :7.0
# episoede :16828  score :2.0
# episoede :16829  score :1.0
# episoede :16830  score :2.0
# episoede :16831  score :1.0
#
# *** Episode 16830 ***
# Av.reward: [last 10]: 3.50, [last 100]: 3.65, [all]: 2.30
# epsilon: 0.01, frames_total: 1691141
# Elapsed time:  09:09:10
# episoede :16832  score :2.0
# episoede :16833  score :1.0
# episoede :16834  score :2.0
# episoede :16835  score :1.0
# episoede :16836  score :12.0
# episoede :16837  score :2.0
# episoede :16838  score :0.0
# episoede :16839  score :2.0
# episoede :16840  score :3.0
# episoede :16841  score :13.0
#
# *** Episode 16840 ***
# Av.reward: [last 10]: 3.80, [last 100]: 3.62, [all]: 2.30
# epsilon: 0.01, frames_total: 1692642
# Elapsed time:  09:09:39
# episoede :16842  score :2.0
# episoede :16843  score :3.0
# episoede :16844  score :0.0
# episoede :16845  score :7.0
# episoede :16846  score :2.0
# episoede :16847  score :1.0
# episoede :16848  score :1.0
# episoede :16849  score :1.0
# episoede :16850  score :1.0
# episoede :16851  score :13.0
#
# *** Episode 16850 ***
# Av.reward: [last 10]: 3.10, [last 100]: 3.62, [all]: 2.30
# epsilon: 0.01, frames_total: 1693814
# Elapsed time:  09:10:01
# episoede :16852  score :2.0
# episoede :16853  score :1.0
# episoede :16854  score :2.0
# episoede :16855  score :1.0
# episoede :16856  score :11.0
# episoede :16857  score :3.0
# episoede :16858  score :5.0
# episoede :16859  score :4.0
# episoede :16860  score :2.0
# episoede :16861  score :6.0
#
# *** Episode 16860 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.59, [all]: 2.30
# epsilon: 0.01, frames_total: 1695243
# Elapsed time:  09:10:28
# episoede :16862  score :1.0
# episoede :16863  score :4.0
# episoede :16864  score :5.0
# episoede :16865  score :1.0
# episoede :16866  score :2.0
# episoede :16867  score :1.0
# episoede :16868  score :1.0
# episoede :16869  score :1.0
# episoede :16870  score :1.0
# episoede :16871  score :1.0
#
# *** Episode 16870 ***
# Av.reward: [last 10]: 1.80, [last 100]: 3.33, [all]: 2.30
# epsilon: 0.01, frames_total: 1696016
# Elapsed time:  09:10:43
# episoede :16872  score :2.0
# episoede :16873  score :4.0
# episoede :16874  score :2.0
# episoede :16875  score :5.0
# episoede :16876  score :3.0
# episoede :16877  score :6.0
# episoede :16878  score :4.0
# episoede :16879  score :1.0
# episoede :16880  score :1.0
# episoede :16881  score :6.0
#
# *** Episode 16880 ***
# Av.reward: [last 10]: 3.40, [last 100]: 3.28, [all]: 2.30
# epsilon: 0.01, frames_total: 1697437
# Elapsed time:  09:11:10
# episoede :16882  score :4.0
# episoede :16883  score :2.0
# episoede :16884  score :0.0
# episoede :16885  score :2.0
# episoede :16886  score :4.0
# episoede :16887  score :1.0
# episoede :16888  score :5.0
# episoede :16889  score :5.0
# episoede :16890  score :1.0
# episoede :16891  score :13.0
#
# *** Episode 16890 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.27, [all]: 2.30
# epsilon: 0.01, frames_total: 1698965
# Elapsed time:  09:11:40
# episoede :16892  score :2.0
# episoede :16893  score :8.0
# episoede :16894  score :1.0
# episoede :16895  score :1.0
# episoede :16896  score :14.0
# episoede :16897  score :2.0
# episoede :16898  score :3.0
# episoede :16899  score :0.0
# episoede :16900  score :0.0
# episoede :16901  score :9.0
#
# *** Episode 16900 ***
# Av.reward: [last 10]: 4.00, [last 100]: 3.27, [all]: 2.30
# epsilon: 0.01, frames_total: 1700584
# Elapsed time:  09:12:12
# episoede :16902  score :6.0
# episoede :16903  score :5.0
# episoede :16904  score :3.0
# episoede :16905  score :0.0
# episoede :16906  score :7.0
# episoede :16907  score :7.0
# episoede :16908  score :1.0
# episoede :16909  score :3.0
# episoede :16910  score :0.0
# episoede :16911  score :4.0
#
# *** Episode 16910 ***
# Av.reward: [last 10]: 3.60, [last 100]: 3.31, [all]: 2.30
# epsilon: 0.01, frames_total: 1701968
# Elapsed time:  09:12:38
# episoede :16912  score :5.0
# episoede :16913  score :2.0
# episoede :16914  score :1.0
# episoede :16915  score :3.0
# episoede :16916  score :5.0
# episoede :16917  score :2.0
# episoede :16918  score :1.0
# episoede :16919  score :3.0
# episoede :16920  score :0.0
# episoede :16921  score :5.0
#
# *** Episode 16920 ***
# Av.reward: [last 10]: 2.70, [last 100]: 3.33, [all]: 2.30
# epsilon: 0.01, frames_total: 1703099
# Elapsed time:  09:12:59
# episoede :16922  score :1.0
# episoede :16923  score :2.0
# episoede :16924  score :2.0
# episoede :16925  score :2.0
# episoede :16926  score :3.0
# episoede :16927  score :1.0
# episoede :16928  score :1.0
# episoede :16929  score :5.0
# episoede :16930  score :4.0
# episoede :16931  score :5.0
#
# *** Episode 16930 ***
# Av.reward: [last 10]: 2.60, [last 100]: 3.24, [all]: 2.30
# epsilon: 0.01, frames_total: 1704099
# Elapsed time:  09:13:19
# episoede :16932  score :5.0
# episoede :16933  score :1.0
# episoede :16934  score :2.0
# episoede :16935  score :0.0
# episoede :16936  score :6.0
# episoede :16937  score :4.0
# episoede :16938  score :1.0
# episoede :16939  score :3.0
# episoede :16940  score :1.0
# episoede :16941  score :2.0
#
# *** Episode 16940 ***
# Av.reward: [last 10]: 2.50, [last 100]: 3.11, [all]: 2.30
# epsilon: 0.01, frames_total: 1705080
# Elapsed time:  09:13:38
# episoede :16942  score :1.0
# episoede :16943  score :5.0
# episoede :16944  score :1.0
# episoede :16945  score :1.0
# episoede :16946  score :4.0
# episoede :16947  score :3.0
# episoede :16948  score :2.0
# episoede :16949  score :2.0
# episoede :16950  score :0.0
# episoede :16951  score :10.0
#
# *** Episode 16950 ***
# Av.reward: [last 10]: 2.90, [last 100]: 3.09, [all]: 2.30
# epsilon: 0.01, frames_total: 1706317
# Elapsed time:  09:14:01
# episoede :16952  score :4.0
# episoede :16953  score :3.0
# episoede :16954  score :2.0
# episoede :16955  score :2.0
# episoede :16956  score :8.0
# episoede :16957  score :6.0
# episoede :16958  score :0.0
# episoede :16959  score :1.0
# episoede :16960  score :1.0
# episoede :16961  score :4.0
#
# *** Episode 16960 ***
# Av.reward: [last 10]: 3.10, [last 100]: 3.03, [all]: 2.31
# epsilon: 0.01, frames_total: 1707536
# Elapsed time:  09:14:24
# episoede :16962  score :5.0
# episoede :16963  score :3.0
# episoede :16964  score :2.0
# episoede :16965  score :2.0
# episoede :16966  score :15.0
# episoede :16967  score :1.0
# episoede :16968  score :1.0
# episoede :16969  score :2.0
# episoede :16970  score :2.0
# episoede :16971  score :6.0
#
# *** Episode 16970 ***
# Av.reward: [last 10]: 3.90, [last 100]: 3.24, [all]: 2.31
# epsilon: 0.01, frames_total: 1709088
# Elapsed time:  09:14:55
# episoede :16972  score :3.0
# episoede :16973  score :5.0
# episoede :16974  score :1.0
# episoede :16975  score :4.0
# episoede :16976  score :6.0
# episoede :16977  score :6.0
# episoede :16978  score :1.0
# episoede :16979  score :2.0
# episoede :16980  score :3.0
# episoede :16981  score :14.0
#
# *** Episode 16980 ***
# Av.reward: [last 10]: 4.50, [last 100]: 3.35, [all]: 2.31
# epsilon: 0.01, frames_total: 1710707
# Elapsed time:  09:15:25
# episoede :16982  score :4.0
# episoede :16983  score :2.0
# episoede :16984  score :1.0
# episoede :16985  score :1.0
# episoede :16986  score :14.0
# episoede :16987  score :2.0
# episoede :16988  score :2.0
# episoede :16989  score :0.0
# episoede :16990  score :0.0
# episoede :16991  score :6.0
#
# *** Episode 16990 ***
# Av.reward: [last 10]: 3.20, [last 100]: 3.30, [all]: 2.31
# epsilon: 0.01, frames_total: 1711983
# Elapsed time:  09:15:49
# episoede :16992  score :5.0
# episoede :16993  score :4.0
# episoede :16994  score :3.0
# episoede :16995  score :4.0
# episoede :16996  score :13.0
# episoede :16997  score :4.0
# episoede :16998  score :2.0
# episoede :16999  score :1.0
# episoede :17000  score :0.0
# episoede :17001  score :11.0
#
# *** Episode 17000 ***
# Av.reward: [last 10]: 4.70, [last 100]: 3.37, [all]: 2.31
# epsilon: 0.01, frames_total: 1713845
# Elapsed time:  09:16:26
# episoede :17002  score :5.0
# episoede :17003  score :2.0
# episoede :17004  score :1.0
# episoede :17005  score :4.0
# episoede :17006  score :6.0
# episoede :17007  score :5.0
# episoede :17008  score :4.0
# episoede :17009  score :2.0
# episoede :17010  score :1.0
# episoede :17011  score :11.0
#
# *** Episode 17010 ***
# Av.reward: [last 10]: 4.10, [last 100]: 3.42, [all]: 2.31
# epsilon: 0.01, frames_total: 1715431
# Elapsed time:  09:16:56
# episoede :17012  score :2.0
# episoede :17013  score :4.0
# episoede :17014  score :4.0
# episoede :17015  score :2.0
# episoede :17016  score :6.0
# episoede :17017  score :4.0
# episoede :17018  score :2.0
# episoede :17019  score :3.0
# episoede :17020  score :2.0
# episoede :17021  score :6.0
#
# *** Episode 17020 ***
# Av.reward: [last 10]: 3.50, [last 100]: 3.50, [all]: 2.31
# epsilon: 0.01, frames_total: 1716757
# Elapsed time:  09:17:22
# episoede :17022  score :3.0
# episoede :17023  score :0.0
# episoede :17024  score :1.0
# episoede :17025  score :0.0
# episoede :17026  score :9.0
# episoede :17027  score :4.0
# episoede :17028  score :7.0
# episoede :17029  score :3.0
# episoede :17030  score :0.0
# episoede :17031  score :11.0
#
# *** Episode 17030 ***
# Av.reward: [last 10]: 3.80, [last 100]: 3.62, [all]: 2.31
# epsilon: 0.01, frames_total: 1718309
# Elapsed time:  09:17:51
# episoede :17032  score :3.0
# episoede :17033  score :2.0
# episoede :17034  score :2.0
# episoede :17035  score :1.0
# episoede :17036  score :13.0
# episoede :17037  score :2.0
# episoede :17038  score :2.0
# episoede :17039  score :1.0
# episoede :17040  score :2.0
# episoede :17041  score :3.0
#
# *** Episode 17040 ***
# Av.reward: [last 10]: 3.10, [last 100]: 3.68, [all]: 2.31
# epsilon: 0.01, frames_total: 1719593
# Elapsed time:  09:18:15
# episoede :17042  score :1.0
# episoede :17043  score :3.0
# episoede :17044  score :6.0
# episoede :17045  score :4.0
# episoede :17046  score :14.0
# episoede :17047  score :0.0
# episoede :17048  score :6.0
# episoede :17049  score :1.0
# episoede :17050  score :3.0
# episoede :17051  score :15.0
#
# *** Episode 17050 ***
# Av.reward: [last 10]: 5.30, [last 100]: 3.92, [all]: 2.31
# epsilon: 0.01, frames_total: 1721571
# Elapsed time:  09:18:53
# episoede :17052  score :4.0
# episoede :17053  score :6.0
# episoede :17054  score :4.0
# episoede :17055  score :2.0
# episoede :17056  score :2.0
# episoede :17057  score :6.0
# episoede :17058  score :3.0
# episoede :17059  score :5.0
# episoede :17060  score :1.0
# episoede :17061  score :12.0
#
# *** Episode 17060 ***
# Av.reward: [last 10]: 4.50, [last 100]: 4.06, [all]: 2.32
# epsilon: 0.01, frames_total: 1723319
# Elapsed time:  09:19:26
# episoede :17062  score :5.0
# episoede :17063  score :1.0
# episoede :17064  score :1.0
# episoede :17065  score :5.0
# episoede :17066  score :13.0
# episoede :17067  score :4.0
# episoede :17068  score :2.0
# episoede :17069  score :4.0
# episoede :17070  score :1.0
# episoede :17071  score :11.0
#
# *** Episode 17070 ***
# Av.reward: [last 10]: 4.70, [last 100]: 4.14, [all]: 2.32
# epsilon: 0.01, frames_total: 1725111
# Elapsed time:  09:20:01
# episoede :17072  score :2.0
# episoede :17073  score :1.0
# episoede :17074  score :0.0
# episoede :17075  score :5.0
# episoede :17076  score :10.0
# episoede :17077  score :0.0
# episoede :17078  score :0.0
# episoede :17079  score :0.0
# episoede :17080  score :0.0
# episoede :17081  score :9.0
#
# *** Episode 17080 ***
# Av.reward: [last 10]: 2.70, [last 100]: 3.96, [all]: 2.32
# epsilon: 0.01, frames_total: 1726253
# Elapsed time:  09:20:23
# episoede :17082  score :5.0
# episoede :17083  score :1.0
# episoede :17084  score :1.0
# episoede :17085  score :1.0
# episoede :17086  score :12.0
# episoede :17087  score :1.0
# episoede :17088  score :2.0
# episoede :17089  score :4.0
# episoede :17090  score :3.0
# episoede :17091  score :16.0
#
# *** Episode 17090 ***
# Av.reward: [last 10]: 4.60, [last 100]: 4.10, [all]: 2.32
# epsilon: 0.01, frames_total: 1728045
# Elapsed time:  09:20:57
# episoede :17092  score :3.0
# episoede :17093  score :4.0
# episoede :17094  score :1.0
# episoede :17095  score :2.0
# episoede :17096  score :2.0
# episoede :17097  score :3.0
# episoede :17098  score :4.0
# episoede :17099  score :5.0
# episoede :17100  score :1.0
# episoede :17101  score :12.0
#
# *** Episode 17100 ***
# Av.reward: [last 10]: 3.70, [last 100]: 4.00, [all]: 2.32
# epsilon: 0.01, frames_total: 1729508
# Elapsed time:  09:21:27
# episoede :17102  score :2.0
# episoede :17103  score :4.0
# episoede :17104  score :0.0
# episoede :17105  score :3.0
# episoede :17106  score :11.0
# episoede :17107  score :1.0
# episoede :17108  score :1.0
# episoede :17109  score :1.0
# episoede :17110  score :1.0
# episoede :17111  score :13.0
#
# *** Episode 17110 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.96, [all]: 2.32
# epsilon: 0.01, frames_total: 1731021
# Elapsed time:  09:21:56
# episoede :17112  score :0.0
# episoede :17113  score :1.0
# episoede :17114  score :4.0
# episoede :17115  score :2.0
# episoede :17116  score :11.0
# episoede :17117  score :0.0
# episoede :17118  score :1.0
# episoede :17119  score :4.0
# episoede :17120  score :3.0
# episoede :17121  score :7.0
#
# *** Episode 17120 ***
# Av.reward: [last 10]: 3.30, [last 100]: 3.94, [all]: 2.32
# epsilon: 0.01, frames_total: 1732449
# Elapsed time:  09:22:23
# episoede :17122  score :4.0
# episoede :17123  score :2.0
# episoede :17124  score :0.0
# episoede :17125  score :1.0
# episoede :17126  score :9.0
# episoede :17127  score :3.0
# episoede :17128  score :0.0
# episoede :17129  score :1.0
# episoede :17130  score :0.0
# episoede :17131  score :12.0
#
# *** Episode 17130 ***
# Av.reward: [last 10]: 3.20, [last 100]: 3.88, [all]: 2.32
# epsilon: 0.01, frames_total: 1733874
# Elapsed time:  09:22:50
# episoede :17132  score :2.0
# episoede :17133  score :3.0
# episoede :17134  score :3.0
# episoede :17135  score :0.0
# episoede :17136  score :10.0
# episoede :17137  score :6.0
# episoede :17138  score :1.0
# episoede :17139  score :0.0
# episoede :17140  score :0.0
# episoede :17141  score :4.0
#
# *** Episode 17140 ***
# Av.reward: [last 10]: 2.90, [last 100]: 3.86, [all]: 2.32
# epsilon: 0.01, frames_total: 1735117
# Elapsed time:  09:23:14
# episoede :17142  score :4.0
# episoede :17143  score :0.0
# episoede :17144  score :2.0
# episoede :17145  score :0.0
# episoede :17146  score :10.0
# episoede :17147  score :3.0
# episoede :17148  score :0.0
# episoede :17149  score :4.0
# episoede :17150  score :3.0
# episoede :17151  score :10.0
#
# *** Episode 17150 ***
# Av.reward: [last 10]: 3.60, [last 100]: 3.69, [all]: 2.32
# epsilon: 0.01, frames_total: 1736638
# Elapsed time:  09:23:43
# episoede :17152  score :2.0
# episoede :17153  score :1.0
# episoede :17154  score :1.0
# episoede :17155  score :0.0
# episoede :17156  score :5.0
# episoede :17157  score :4.0
# episoede :17158  score :9.0
# episoede :17159  score :1.0
# episoede :17160  score :5.0
# episoede :17161  score :4.0
#
# *** Episode 17160 ***
# Av.reward: [last 10]: 3.20, [last 100]: 3.56, [all]: 2.32
# epsilon: 0.01, frames_total: 1737945
# Elapsed time:  09:24:08
# episoede :17162  score :4.0
# episoede :17163  score :2.0
# episoede :17164  score :2.0
# episoede :17165  score :3.0
# episoede :17166  score :10.0
# episoede :17167  score :2.0
# episoede :17168  score :5.0
# episoede :17169  score :1.0
# episoede :17170  score :10.0
# episoede :17171  score :12.0
#
# *** Episode 17170 ***
# Av.reward: [last 10]: 5.10, [last 100]: 3.60, [all]: 2.32
# epsilon: 0.01, frames_total: 1739990
# Elapsed time:  09:24:47
# episoede :17172  score :2.0
# episoede :17173  score :4.0
# episoede :17174  score :2.0
# episoede :17175  score :1.0
# episoede :17176  score :6.0
# episoede :17177  score :2.0
# episoede :17178  score :3.0
# episoede :17179  score :0.0
# episoede :17180  score :1.0
# episoede :17181  score :12.0
#
# *** Episode 17180 ***
# Av.reward: [last 10]: 3.30, [last 100]: 3.66, [all]: 2.32
# epsilon: 0.01, frames_total: 1741433
# Elapsed time:  09:25:15
# episoede :17182  score :4.0
# episoede :17183  score :1.0
# episoede :17184  score :2.0
# episoede :17185  score :2.0
# episoede :17186  score :12.0
# episoede :17187  score :2.0
# episoede :17188  score :1.0
# episoede :17189  score :2.0
# episoede :17190  score :3.0
# episoede :17191  score :12.0
#
# *** Episode 17190 ***
# Av.reward: [last 10]: 4.10, [last 100]: 3.61, [all]: 2.33
# epsilon: 0.01, frames_total: 1743048
# Elapsed time:  09:25:45
# episoede :17192  score :0.0
# episoede :17193  score :2.0
# episoede :17194  score :3.0
# episoede :17195  score :2.0
# episoede :17196  score :12.0
# episoede :17197  score :2.0
# episoede :17198  score :5.0
# episoede :17199  score :4.0
# episoede :17200  score :0.0
# episoede :17201  score :12.0
#
# *** Episode 17200 ***
# Av.reward: [last 10]: 4.20, [last 100]: 3.66, [all]: 2.33
# epsilon: 0.01, frames_total: 1744754
# Elapsed time:  09:26:19
# episoede :17202  score :2.0
# episoede :17203  score :2.0
# episoede :17204  score :3.0
# episoede :17205  score :0.0
# episoede :17206  score :13.0
# episoede :17207  score :1.0
# episoede :17208  score :1.0
# episoede :17209  score :2.0
# episoede :17210  score :2.0
# episoede :17211  score :16.0
#
# *** Episode 17210 ***
# Av.reward: [last 10]: 4.20, [last 100]: 3.71, [all]: 2.33
# epsilon: 0.01, frames_total: 1746473
# Elapsed time:  09:26:53
# episoede :17212  score :1.0
# episoede :17213  score :1.0
# episoede :17214  score :2.0
# episoede :17215  score :2.0
# episoede :17216  score :15.0
# episoede :17217  score :5.0
# episoede :17218  score :3.0
# episoede :17219  score :3.0
# episoede :17220  score :0.0
# episoede :17221  score :0.0
#
# *** Episode 17220 ***
# Av.reward: [last 10]: 3.20, [last 100]: 3.70, [all]: 2.33
# epsilon: 0.01, frames_total: 1747686
# Elapsed time:  09:27:16
# episoede :17222  score :4.0
# episoede :17223  score :3.0
# episoede :17224  score :6.0
# episoede :17225  score :1.0
# episoede :17226  score :14.0
# episoede :17227  score :1.0
# episoede :17228  score :2.0
# episoede :17229  score :3.0
# episoede :17230  score :1.0
# episoede :17231  score :5.0
#
# *** Episode 17230 ***
# Av.reward: [last 10]: 4.00, [last 100]: 3.78, [all]: 2.33
# epsilon: 0.01, frames_total: 1749231
# Elapsed time:  09:27:45
# episoede :17232  score :0.0
# episoede :17233  score :4.0
# episoede :17234  score :1.0
# episoede :17235  score :0.0
# episoede :17236  score :6.0
# episoede :17237  score :4.0
# episoede :17238  score :4.0
# episoede :17239  score :5.0
# episoede :17240  score :2.0
# episoede :17241  score :12.0
#
# *** Episode 17240 ***
# Av.reward: [last 10]: 3.80, [last 100]: 3.87, [all]: 2.33
# epsilon: 0.01, frames_total: 1750748
# Elapsed time:  09:28:14
# episoede :17242  score :3.0
# episoede :17243  score :4.0
# episoede :17244  score :0.0
# episoede :17245  score :1.0
# episoede :17246  score :12.0
# episoede :17247  score :2.0
# episoede :17248  score :3.0
# episoede :17249  score :1.0
# episoede :17250  score :0.0
# episoede :17251  score :1.0
#
# *** Episode 17250 ***
# Av.reward: [last 10]: 2.70, [last 100]: 3.78, [all]: 2.33
# epsilon: 0.01, frames_total: 1751873
# Elapsed time:  09:28:36
# episoede :17252  score :1.0
# episoede :17253  score :5.0
# episoede :17254  score :1.0
# episoede :17255  score :3.0
# episoede :17256  score :4.0
# episoede :17257  score :6.0
# episoede :17258  score :4.0
# episoede :17259  score :1.0
# episoede :17260  score :0.0
# episoede :17261  score :10.0
#
# *** Episode 17260 ***
# Av.reward: [last 10]: 3.50, [last 100]: 3.81, [all]: 2.33
# epsilon: 0.01, frames_total: 1753303
# Elapsed time:  09:29:03
# episoede :17262  score :4.0
# episoede :17263  score :3.0
# episoede :17264  score :2.0
# episoede :17265  score :1.0
# episoede :17266  score :12.0
# episoede :17267  score :2.0
# episoede :17268  score :4.0
# episoede :17269  score :5.0
# episoede :17270  score :1.0
# episoede :17271  score :6.0
#
# *** Episode 17270 ***
# Av.reward: [last 10]: 4.00, [last 100]: 3.70, [all]: 2.33
# epsilon: 0.01, frames_total: 1754895
# Elapsed time:  09:29:33
# episoede :17272  score :3.0
# episoede :17273  score :4.0
# episoede :17274  score :3.0
# episoede :17275  score :0.0
# episoede :17276  score :3.0
# episoede :17277  score :1.0
# episoede :17278  score :4.0
# episoede :17279  score :3.0
# episoede :17280  score :2.0
# episoede :17281  score :2.0
#
# *** Episode 17280 ***
# Av.reward: [last 10]: 2.50, [last 100]: 3.62, [all]: 2.33
# epsilon: 0.01, frames_total: 1756035
# Elapsed time:  09:29:55
# episoede :17282  score :2.0
# episoede :17283  score :4.0
# episoede :17284  score :7.0
# episoede :17285  score :1.0
# episoede :17286  score :7.0
# episoede :17287  score :6.0
# episoede :17288  score :4.0
# episoede :17289  score :2.0
# episoede :17290  score :2.0
# episoede :17291  score :6.0
#
# *** Episode 17290 ***
# Av.reward: [last 10]: 4.10, [last 100]: 3.62, [all]: 2.33
# epsilon: 0.01, frames_total: 1757568
# Elapsed time:  09:30:25
# episoede :17292  score :3.0
# episoede :17293  score :4.0
# episoede :17294  score :1.0
# episoede :17295  score :1.0
# episoede :17296  score :7.0
# episoede :17297  score :3.0
# episoede :17298  score :3.0
# episoede :17299  score :2.0
# episoede :17300  score :1.0
# episoede :17301  score :12.0
#
# *** Episode 17300 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.57, [all]: 2.33
# epsilon: 0.01, frames_total: 1759073
# Elapsed time:  09:30:56
# episoede :17302  score :2.0
# episoede :17303  score :0.0
# episoede :17304  score :7.0
# episoede :17305  score :3.0
# episoede :17306  score :13.0
# episoede :17307  score :5.0
# episoede :17308  score :3.0
# episoede :17309  score :3.0
# episoede :17310  score :1.0
# episoede :17311  score :12.0
#
# *** Episode 17310 ***
# Av.reward: [last 10]: 4.90, [last 100]: 3.64, [all]: 2.34
# epsilon: 0.01, frames_total: 1760993
# Elapsed time:  09:31:32
# episoede :17312  score :4.0
# episoede :17313  score :1.0
# episoede :17314  score :4.0
# episoede :17315  score :0.0
# episoede :17316  score :14.0
# episoede :17317  score :0.0
# episoede :17318  score :3.0
# episoede :17319  score :0.0
# episoede :17320  score :2.0
# episoede :17321  score :7.0
#
# *** Episode 17320 ***
# Av.reward: [last 10]: 3.50, [last 100]: 3.67, [all]: 2.34
# epsilon: 0.01, frames_total: 1762343
# Elapsed time:  09:31:58
# episoede :17322  score :5.0
# episoede :17323  score :3.0
# episoede :17324  score :3.0
# episoede :17325  score :2.0
# episoede :17326  score :6.0
# episoede :17327  score :3.0
# episoede :17328  score :4.0
# episoede :17329  score :2.0
# episoede :17330  score :1.0
# episoede :17331  score :15.0
#
# *** Episode 17330 ***
# Av.reward: [last 10]: 4.40, [last 100]: 3.71, [all]: 2.34
# epsilon: 0.01, frames_total: 1763974
# Elapsed time:  09:32:29
# episoede :17332  score :2.0
# episoede :17333  score :5.0
# episoede :17334  score :3.0
# episoede :17335  score :1.0
# episoede :17336  score :6.0
# episoede :17337  score :1.0
# episoede :17338  score :2.0
# episoede :17339  score :4.0
# episoede :17340  score :3.0
# episoede :17341  score :3.0
#
# *** Episode 17340 ***
# Av.reward: [last 10]: 3.00, [last 100]: 3.63, [all]: 2.34
# epsilon: 0.01, frames_total: 1765278
# Elapsed time:  09:32:55
# episoede :17342  score :3.0
# episoede :17343  score :3.0
# episoede :17344  score :1.0
# episoede :17345  score :1.0
# episoede :17346  score :4.0
# episoede :17347  score :4.0
# episoede :17348  score :7.0
# episoede :17349  score :1.0
# episoede :17350  score :0.0
# episoede :17351  score :15.0
#
# *** Episode 17350 ***
# Av.reward: [last 10]: 3.90, [last 100]: 3.75, [all]: 2.34
# epsilon: 0.01, frames_total: 1766826
# Elapsed time:  09:33:24
# episoede :17352  score :1.0
# episoede :17353  score :6.0
# episoede :17354  score :1.0
# episoede :17355  score :2.0
# episoede :17356  score :10.0
# episoede :17357  score :5.0
# episoede :17358  score :0.0
# episoede :17359  score :2.0
# episoede :17360  score :0.0
# episoede :17361  score :17.0
#
# *** Episode 17360 ***
# Av.reward: [last 10]: 4.40, [last 100]: 3.84, [all]: 2.34
# epsilon: 0.01, frames_total: 1768487
# Elapsed time:  09:33:56
# episoede :17362  score :2.0
# episoede :17363  score :2.0
# episoede :17364  score :2.0
# episoede :17365  score :1.0
# episoede :17366  score :9.0
# episoede :17367  score :5.0
# episoede :17368  score :1.0
# episoede :17369  score :2.0
# episoede :17370  score :6.0
# episoede :17371  score :7.0
#
# *** Episode 17370 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.81, [all]: 2.34
# epsilon: 0.01, frames_total: 1769931
# Elapsed time:  09:34:24
# episoede :17372  score :4.0
# episoede :17373  score :5.0
# episoede :17374  score :1.0
# episoede :17375  score :1.0
# episoede :17376  score :10.0
# episoede :17377  score :4.0
# episoede :17378  score :0.0
# episoede :17379  score :3.0
# episoede :17380  score :0.0
# episoede :17381  score :11.0
#
# *** Episode 17380 ***
# Av.reward: [last 10]: 3.90, [last 100]: 3.95, [all]: 2.34
# epsilon: 0.01, frames_total: 1771531
# Elapsed time:  09:34:54
# episoede :17382  score :2.0
# episoede :17383  score :0.0
# episoede :17384  score :4.0
# episoede :17385  score :0.0
# episoede :17386  score :6.0
# episoede :17387  score :2.0
# episoede :17388  score :4.0
# episoede :17389  score :1.0
# episoede :17390  score :2.0
# episoede :17391  score :6.0
#
# *** Episode 17390 ***
# Av.reward: [last 10]: 2.70, [last 100]: 3.81, [all]: 2.34
# epsilon: 0.01, frames_total: 1772628
# Elapsed time:  09:35:15
# episoede :17392  score :5.0
# episoede :17393  score :3.0
# episoede :17394  score :2.0
# episoede :17395  score :1.0
# episoede :17396  score :4.0
# episoede :17397  score :4.0
# episoede :17398  score :2.0
# episoede :17399  score :2.0
# episoede :17400  score :2.0
# episoede :17401  score :14.0
#
# *** Episode 17400 ***
# Av.reward: [last 10]: 3.90, [last 100]: 3.83, [all]: 2.34
# epsilon: 0.01, frames_total: 1774134
# Elapsed time:  09:35:46
# episoede :17402  score :3.0
# episoede :17403  score :2.0
# episoede :17404  score :0.0
# episoede :17405  score :0.0
# episoede :17406  score :5.0
# episoede :17407  score :3.0
# episoede :17408  score :4.0
# episoede :17409  score :3.0
# episoede :17410  score :5.0
# episoede :17411  score :10.0
#
# *** Episode 17410 ***
# Av.reward: [last 10]: 3.50, [last 100]: 3.69, [all]: 2.34
# epsilon: 0.01, frames_total: 1775566
# Elapsed time:  09:36:14
# episoede :17412  score :3.0
# episoede :17413  score :8.0
# episoede :17414  score :0.0
# episoede :17415  score :1.0
# episoede :17416  score :11.0
# episoede :17417  score :3.0
# episoede :17418  score :1.0
# episoede :17419  score :1.0
# episoede :17420  score :3.0
# episoede :17421  score :15.0
#
# *** Episode 17420 ***
# Av.reward: [last 10]: 4.60, [last 100]: 3.80, [all]: 2.34
# epsilon: 0.01, frames_total: 1777285
# Elapsed time:  09:36:47
# episoede :17422  score :2.0
# episoede :17423  score :3.0
# episoede :17424  score :1.0
# episoede :17425  score :1.0
# episoede :17426  score :9.0
# episoede :17427  score :2.0
# episoede :17428  score :2.0
# episoede :17429  score :1.0
# episoede :17430  score :1.0
# episoede :17431  score :8.0
#
# *** Episode 17430 ***
# Av.reward: [last 10]: 3.00, [last 100]: 3.66, [all]: 2.35
# epsilon: 0.01, frames_total: 1778615
# Elapsed time:  09:37:13
# episoede :17432  score :5.0
# episoede :17433  score :2.0
# episoede :17434  score :2.0
# episoede :17435  score :1.0
# episoede :17436  score :11.0
# episoede :17437  score :1.0
# episoede :17438  score :4.0
# ...
# episoede :19444  score :4.0
# episoede :19445  score :1.0
# episoede :19446  score :6.0
# episoede :19447  score :12.0
# episoede :19448  score :3.0
# episoede :19449  score :1.0
# episoede :19450  score :1.0
# episoede :19451  score :8.0
#
# *** Episode 19450 ***
# Av.reward: [last 10]: 3.80, [last 100]: 3.92, [all]: 2.49
# epsilon: 0.01, frames_total: 2081624
# Elapsed time:  11:15:08
# episoede :19452  score :1.0
# episoede :19453  score :1.0
# episoede :19454  score :0.0
# episoede :19455  score :1.0
# episoede :19456  score :11.0
# episoede :19457  score :3.0
# episoede :19458  score :0.0
# episoede :19459  score :1.0
# episoede :19460  score :2.0
# episoede :19461  score :13.0
#
# *** Episode 19460 ***
# Av.reward: [last 10]: 3.30, [last 100]: 3.93, [all]: 2.49
# epsilon: 0.01, frames_total: 2083053
# Elapsed time:  11:15:35
# episoede :19462  score :1.0
# episoede :19463  score :4.0
# episoede :19464  score :4.0
# episoede :19465  score :1.0
# episoede :19466  score :4.0
# episoede :19467  score :4.0
# episoede :19468  score :4.0
# episoede :19469  score :3.0
# episoede :19470  score :3.0
# episoede :19471  score :7.0
#
# *** Episode 19470 ***
# Av.reward: [last 10]: 3.50, [last 100]: 3.85, [all]: 2.49
# epsilon: 0.01, frames_total: 2084429
# Elapsed time:  11:16:02
# episoede :19472  score :4.0
# episoede :19473  score :1.0
# episoede :19474  score :1.0
# episoede :19475  score :0.0
# episoede :19476  score :9.0
# episoede :19477  score :11.0
# episoede :19478  score :1.0
# episoede :19479  score :1.0
# episoede :19480  score :1.0
# episoede :19481  score :10.0
#
# *** Episode 19480 ***
# Av.reward: [last 10]: 3.90, [last 100]: 3.95, [all]: 2.49
# epsilon: 0.01, frames_total: 2086014
# Elapsed time:  11:16:31
# episoede :19482  score :7.0
# episoede :19483  score :2.0
# episoede :19484  score :3.0
# episoede :19485  score :6.0
# episoede :19486  score :12.0
# episoede :19487  score :4.0
# episoede :19488  score :0.0
# episoede :19489  score :0.0
# episoede :19490  score :4.0
# episoede :19491  score :13.0
#
# *** Episode 19490 ***
# Av.reward: [last 10]: 5.10, [last 100]: 4.05, [all]: 2.50
# epsilon: 0.01, frames_total: 2087975
# Elapsed time:  11:17:09
# episoede :19492  score :1.0
# episoede :19493  score :4.0
# episoede :19494  score :3.0
# episoede :19495  score :1.0
# episoede :19496  score :4.0
# episoede :19497  score :3.0
# episoede :19498  score :2.0
# episoede :19499  score :5.0
# episoede :19500  score :2.0
# episoede :19501  score :6.0
#
# *** Episode 19500 ***
# Av.reward: [last 10]: 3.10, [last 100]: 3.98, [all]: 2.50
# epsilon: 0.01, frames_total: 2089231
# Elapsed time:  11:17:35
# episoede :19502  score :1.0
# episoede :19503  score :1.0
# episoede :19504  score :4.0
# episoede :19505  score :1.0
# episoede :19506  score :11.0
# episoede :19507  score :4.0
# episoede :19508  score :1.0
# episoede :19509  score :5.0
# episoede :19510  score :0.0
# episoede :19511  score :11.0
#
# *** Episode 19510 ***
# Av.reward: [last 10]: 3.90, [last 100]: 3.88, [all]: 2.50
# epsilon: 0.01, frames_total: 2090827
# Elapsed time:  11:18:05
# episoede :19512  score :4.0
# episoede :19513  score :0.0
# episoede :19514  score :0.0
# episoede :19515  score :3.0
# episoede :19516  score :1.0
# episoede :19517  score :4.0
# episoede :19518  score :2.0
# episoede :19519  score :3.0
# episoede :19520  score :4.0
# episoede :19521  score :7.0
#
# *** Episode 19520 ***
# Av.reward: [last 10]: 2.80, [last 100]: 3.75, [all]: 2.50
# epsilon: 0.01, frames_total: 2091985
# Elapsed time:  11:18:27
# episoede :19522  score :3.0
# episoede :19523  score :3.0
# episoede :19524  score :2.0
# episoede :19525  score :2.0
# episoede :19526  score :5.0
# episoede :19527  score :1.0
# episoede :19528  score :4.0
# episoede :19529  score :2.0
# episoede :19530  score :4.0
# episoede :19531  score :4.0
#
# *** Episode 19530 ***
# Av.reward: [last 10]: 3.00, [last 100]: 3.64, [all]: 2.50
# epsilon: 0.01, frames_total: 2093219
# Elapsed time:  11:18:51
# episoede :19532  score :4.0
# episoede :19533  score :1.0
# episoede :19534  score :3.0
# episoede :19535  score :0.0
# episoede :19536  score :7.0
# episoede :19537  score :5.0
# episoede :19538  score :4.0
# episoede :19539  score :1.0
# episoede :19540  score :1.0
# episoede :19541  score :7.0
#
# *** Episode 19540 ***
# Av.reward: [last 10]: 3.30, [last 100]: 3.57, [all]: 2.50
# epsilon: 0.01, frames_total: 2094530
# Elapsed time:  11:19:16
# episoede :19542  score :5.0
# episoede :19543  score :2.0
# episoede :19544  score :0.0
# episoede :19545  score :4.0
# episoede :19546  score :12.0
# episoede :19547  score :6.0
# episoede :19548  score :3.0
# episoede :19549  score :1.0
# episoede :19550  score :1.0
# episoede :19551  score :4.0
#
# *** Episode 19550 ***
# Av.reward: [last 10]: 3.80, [last 100]: 3.57, [all]: 2.50
# epsilon: 0.01, frames_total: 2096058
# Elapsed time:  11:19:45
# episoede :19552  score :2.0
# episoede :19553  score :2.0
# episoede :19554  score :3.0
# episoede :19555  score :0.0
# episoede :19556  score :6.0
# episoede :19557  score :2.0
# episoede :19558  score :0.0
# episoede :19559  score :5.0
# episoede :19560  score :1.0
# episoede :19561  score :8.0
#
# *** Episode 19560 ***
# Av.reward: [last 10]: 2.90, [last 100]: 3.53, [all]: 2.50
# epsilon: 0.01, frames_total: 2097327
# Elapsed time:  11:20:09
# episoede :19562  score :2.0
# episoede :19563  score :4.0
# episoede :19564  score :4.0
# episoede :19565  score :3.0
# episoede :19566  score :7.0
# episoede :19567  score :5.0
# episoede :19568  score :4.0
# episoede :19569  score :3.0
# episoede :19570  score :3.0
# episoede :19571  score :7.0
#
# *** Episode 19570 ***
# Av.reward: [last 10]: 4.20, [last 100]: 3.60, [all]: 2.50
# epsilon: 0.01, frames_total: 2098946
# Elapsed time:  11:20:40
# episoede :19572  score :3.0
# episoede :19573  score :2.0
# episoede :19574  score :4.0
# episoede :19575  score :5.0
# episoede :19576  score :11.0
# episoede :19577  score :5.0
# episoede :19578  score :3.0
# episoede :19579  score :1.0
# episoede :19580  score :2.0
# episoede :19581  score :1.0
#
# *** Episode 19580 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.58, [all]: 2.50
# epsilon: 0.01, frames_total: 2100394
# Elapsed time:  11:21:07
# episoede :19582  score :5.0
# episoede :19583  score :2.0
# episoede :19584  score :3.0
# episoede :19585  score :1.0
# episoede :19586  score :9.0
# episoede :19587  score :5.0
# episoede :19588  score :0.0
# episoede :19589  score :5.0
# episoede :19590  score :2.0
# episoede :19591  score :2.0
#
# *** Episode 19590 ***
# Av.reward: [last 10]: 3.40, [last 100]: 3.41, [all]: 2.50
# epsilon: 0.01, frames_total: 2101823
# Elapsed time:  11:21:35
# episoede :19592  score :4.0
# episoede :19593  score :1.0
# episoede :19594  score :3.0
# episoede :19595  score :1.0
# episoede :19596  score :6.0
# episoede :19597  score :4.0
# episoede :19598  score :1.0
# episoede :19599  score :3.0
# episoede :19600  score :1.0
# episoede :19601  score :12.0
#
# *** Episode 19600 ***
# Av.reward: [last 10]: 3.60, [last 100]: 3.46, [all]: 2.50
# epsilon: 0.01, frames_total: 2103322
# Elapsed time:  11:22:05
# episoede :19602  score :7.0
# episoede :19603  score :3.0
# episoede :19604  score :4.0
# episoede :19605  score :0.0
# episoede :19606  score :14.0
# episoede :19607  score :7.0
# episoede :19608  score :2.0
# episoede :19609  score :0.0
# episoede :19610  score :0.0
# episoede :19611  score :13.0
#
# *** Episode 19610 ***
# Av.reward: [last 10]: 5.00, [last 100]: 3.57, [all]: 2.50
# epsilon: 0.01, frames_total: 2105256
# Elapsed time:  11:22:42
# episoede :19612  score :3.0
# episoede :19613  score :3.0
# episoede :19614  score :3.0
# episoede :19615  score :1.0
# episoede :19616  score :6.0
# episoede :19617  score :4.0
# episoede :19618  score :3.0
# episoede :19619  score :2.0
# episoede :19620  score :2.0
# episoede :19621  score :11.0
#
# *** Episode 19620 ***
# Av.reward: [last 10]: 3.80, [last 100]: 3.67, [all]: 2.50
# epsilon: 0.01, frames_total: 2106861
# Elapsed time:  11:23:12
# episoede :19622  score :2.0
# episoede :19623  score :2.0
# episoede :19624  score :5.0
# episoede :19625  score :5.0
# episoede :19626  score :6.0
# episoede :19627  score :1.0
# episoede :19628  score :1.0
# episoede :19629  score :3.0
# episoede :19630  score :1.0
# episoede :19631  score :11.0
#
# *** Episode 19630 ***
# Av.reward: [last 10]: 3.70, [last 100]: 3.74, [all]: 2.50
# epsilon: 0.01, frames_total: 2108361
# Elapsed time:  11:23:41
# episoede :19632  score :4.0
# episoede :19633  score :3.0
# episoede :19634  score :1.0
# episoede :19635  score :2.0
# episoede :19636  score :6.0
# episoede :19637  score :5.0
# episoede :19638  score :0.0
# episoede :19639  score :0.0
# episoede :19640  score :7.0
# episoede :19641  score :10.0
#
# *** Episode 19640 ***
# Av.reward: [last 10]: 3.80, [last 100]: 3.79, [all]: 2.50
# epsilon: 0.01, frames_total: 2109789
# Elapsed time:  11:24:08
# episoede :19642  score :8.0
# episoede :19643  score :3.0
# episoede :19644  score :2.0
# episoede :19645  score :0.0
# episoede :19646  score :2.0
# episoede :19647  score :0.0
# episoede :19648  score :2.0
# episoede :19649  score :2.0
# episoede :19650  score :2.0
# episoede :19651  score :7.0
#
# *** Episode 19650 ***
# Av.reward: [last 10]: 2.80, [last 100]: 3.69, [all]: 2.50
# epsilon: 0.01, frames_total: 2111054
# Elapsed time:  11:24:33
# episoede :19652  score :5.0
# episoede :19653  score :3.0
# episoede :19654  score :1.0
# episoede :19655  score :0.0
# episoede :19656  score :4.0
# episoede :19657  score :2.0
# episoede :19658  score :0.0
# episoede :19659  score :1.0
# episoede :19660  score :3.0
# episoede :19661  score :1.0
#
# *** Episode 19660 ***
# Av.reward: [last 10]: 2.00, [last 100]: 3.60, [all]: 2.50
# epsilon: 0.01, frames_total: 2111958
# Elapsed time:  11:24:50
# episoede :19662  score :2.0
# episoede :19663  score :0.0
# episoede :19664  score :2.0
# episoede :19665  score :3.0
# episoede :19666  score :4.0
# episoede :19667  score :2.0
# episoede :19668  score :0.0
# episoede :19669  score :4.0
# episoede :19670  score :2.0
# episoede :19671  score :4.0
#
# *** Episode 19670 ***
# Av.reward: [last 10]: 2.30, [last 100]: 3.41, [all]: 2.50
# epsilon: 0.01, frames_total: 2113046
# Elapsed time:  11:25:11
# episoede :19672  score :4.0
# episoede :19673  score :3.0
# episoede :19674  score :5.0
# episoede :19675  score :3.0
# episoede :19676  score :2.0
# episoede :19677  score :0.0
# episoede :19678  score :2.0
# episoede :19679  score :1.0
# episoede :19680  score :7.0
# episoede :19681  score :14.0
#
# *** Episode 19680 ***
# Av.reward: [last 10]: 4.10, [last 100]: 3.45, [all]: 2.50
# epsilon: 0.01, frames_total: 2114629
# Elapsed time:  11:25:41
# episoede :19682  score :2.0
# episoede :19683  score :1.0
# episoede :19684  score :0.0
# episoede :19685  score :4.0
# episoede :19686  score :11.0
# episoede :19687  score :5.0
# episoede :19688  score :3.0
# episoede :19689  score :4.0
# episoede :19690  score :3.0
# episoede :19691  score :7.0
#
# *** Episode 19690 ***
# Av.reward: [last 10]: 4.00, [last 100]: 3.51, [all]: 2.50
# epsilon: 0.01, frames_total: 2116169
# Elapsed time:  11:26:11
# episoede :19692  score :1.0
# episoede :19693  score :2.0
# episoede :19694  score :6.0
# episoede :19695  score :2.0
# episoede :19696  score :3.0
# episoede :19697  score :1.0
# episoede :19698  score :1.0
# episoede :19699  score :4.0
# episoede :19700  score :1.0
# episoede :19701  score :10.0
#
# *** Episode 19700 ***
# Av.reward: [last 10]: 3.10, [last 100]: 3.46, [all]: 2.51
# epsilon: 0.01, frames_total: 2117495
# Elapsed time:  11:26:38
# episoede :19702  score :3.0
# episoede :19703  score :4.0
# episoede :19704  score :1.0
# episoede :19705  score :1.0
# episoede :19706  score :14.0
# episoede :19707  score :6.0
# episoede :19708  score :2.0
# episoede :19709  score :0.0
# episoede :19710  score :1.0
# episoede :19711  score :14.0
#
# *** Episode 19710 ***
# Av.reward: [last 10]: 4.60, [last 100]: 3.42, [all]: 2.51
# epsilon: 0.01, frames_total: 2119272
# Elapsed time:  11:27:12
# episoede :19712  score :3.0
# episoede :19713  score :1.0
# episoede :19714  score :2.0
# episoede :19715  score :5.0
# episoede :19716  score :12.0
# episoede :19717  score :1.0
# episoede :19718  score :2.0
# episoede :19719  score :1.0
# episoede :19720  score :1.0
# episoede :19721  score :2.0
#
# *** Episode 19720 ***
# Av.reward: [last 10]: 3.00, [last 100]: 3.34, [all]: 2.51
# epsilon: 0.01, frames_total: 2120477
# Elapsed time:  11:27:36
# episoede :19722  score :3.0
# episoede :19723  score :9.0
# episoede :19724  score :6.0
# episoede :19725  score :0.0
# episoede :19726  score :3.0
# episoede :19727  score :1.0
# episoede :19728  score :2.0
# episoede :19729  score :4.0
# episoede :19730  score :1.0
# episoede :19731  score :2.0
#
# *** Episode 19730 ***
# Av.reward: [last 10]: 3.10, [last 100]: 3.28, [all]: 2.51
# epsilon: 0.01, frames_total: 2121822
# Elapsed time:  11:28:02
# episoede :19732  score :5.0
# episoede :19733  score :2.0
# episoede :19734  score :2.0
# episoede :19735  score :1.0
# episoede :19736  score :3.0
# episoede :19737  score :3.0
# episoede :19738  score :2.0
# episoede :19739  score :3.0
# episoede :19740  score :1.0
# episoede :19741  score :17.0
#
# *** Episode 19740 ***
# Av.reward: [last 10]: 3.90, [last 100]: 3.29, [all]: 2.51
# epsilon: 0.01, frames_total: 2123407
# Elapsed time:  11:28:32
# episoede :19742  score :5.0
# episoede :19743  score :2.0
# episoede :19744  score :1.0
# episoede :19745  score :2.0
# episoede :19746  score :9.0
# episoede :19747  score :4.0
# episoede :19748  score :1.0
# episoede :19749  score :1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-35dc22aaac67> in <module>()
#     277
#     278         memory.push(state, action, new_state, reward, done)
# --> 279         qnet_agent.optimize()
#     280
#     281         state = new_state
#
# <ipython-input-6-35dc22aaac67> in optimize(self)
#     213             max_new_state_indexes = torch.max(new_state_indexes, 1)[1]
#     214
# --> 215             new_state_values = self.target_nn(new_state).detach()
#     216             max_new_state_values = new_state_values.gather(1, max_new_state_indexes.unsqueeze(1)).squeeze(1)
#     217         else:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-6-35dc22aaac67> in forward(self, x)
#     144         output_conv = output_conv.view(output_conv.size(0), -1)
#     145
# --> 146         output_advantage = self.advantage1(output_conv)
#     147         output_advantage = self.activation(output_advantage)
#     148         output_advantage = self.advantage2(output_advantage)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     763             self._non_persistent_buffers_set = set()
#     764
# --> 765     def __getattr__(self, name: str) -> Union[Tensor, 'Module']:
#     766         if '_parameters' in self.__dict__:
#     767             _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %%
#I interupted the exuction above as it was running for 11 hours
